# %% [markdown]
# ### 1. 라이브러리선언

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. 데이터 불러오기

# %%
joinMaster = \
    pd.read_csv("../dataset/join_region_master.csv", encoding="ms949")

# %%
joinMaster = joinMaster.rename(columns={"REGIONID":"AP2ID"})

# %%
joinMaster
# Out:
#   AP2ID REGIONNAME
# 0   A01         한국
# 1   A02         미국
# 2   A03        프랑스
# 3   A04         독일

# %%
joinSellout = \
    pd.read_csv("../dataset/join_kopo_product_volume.csv")

# %%
joinSellout
# Out:
#   REGIONID PRODUCT  YEARWEEK   QTY
# 0      A01  ST0001    201901  3000
# 1      A01  ST0001    201902  3500
# 2      A02  ST0002    201901  4000
# 3      A02  ST0003    201902  7000

# %% [markdown]
# ### 3. 데이터 병합

# %%
joinMaster.loc[4,"AP2ID"] = "A05"
joinMaster.loc[4, "REGIONNAME"] = "인도"

# %%
joinMaster2 = joinMaster.loc[joinMaster.AP2ID == "A01"]

# %%
pd.merge(left=joinSellout,
        right=joinMaster,
        left_on="REGIONID", #왼쪽에서는 REGIONID 컬럼을
        right_on="AP2ID",   #오른쪽에서는 AP2ID 컬럼을
        how="outer")
# Out:
#   REGIONID PRODUCT  YEARWEEK     QTY AP2ID REGIONNAME
# 0      A01  ST0001  201901.0  3000.0   A01         한국
# 1      A01  ST0001  201902.0  3500.0   A01         한국
# 2      A02  ST0002  201901.0  4000.0   A02         미국
# 3      A02  ST0003  201902.0  7000.0   A02         미국
# 4      NaN     NaN       NaN     NaN   A03        프랑스
# 5      NaN     NaN       NaN     NaN   A04         독일
# 6      NaN     NaN       NaN     NaN   A05         인도

# %%
joinMaster
# Out:
#   AP2ID REGIONNAME
# 0   A01         한국
# 1   A02         미국
# 2   A03        프랑스
# 3   A04         독일
# 4   A05         인도

# %%
joinSellout
# Out:
#   REGIONID PRODUCT  YEARWEEK   QTY
# 0      A01  ST0001    201901  3000
# 1      A01  ST0001    201902  3500
# 2      A02  ST0002    201901  4000
# 3      A02  ST0003    201902  7000

# %%
columnList = ["REGIONID","PRODUCT", "DATE", "QTY"]

# %%
data1 = pd.DataFrame (
[["서울","AA카드", 20210518, 100],
 ["서울", "AA카드", 20210517, 100],
 ["서울", "AA카드", 20210516, 100],
 ["서울", "AA카드", 20210515, 100],
 ["서울", "AA카드", 20210514, 100]], columns = columnList)

# %%
#한가지 테이블을 복사해서
data4 = data3.copy()

# %%
#컬럼명안의 내용 바꾸기
data4.PRODUCT = "BB카드"

# %%
data1
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       서울    AA카드  20210518  100
# 1       서울    AA카드  20210517  100
# 2       서울    AA카드  20210516  100
# 3       서울    AA카드  20210515  100
# 4       서울    AA카드  20210514  100

# %%
data2
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       서울    BB카드  20210518  100
# 1       서울    BB카드  20210517  100
# 2       서울    BB카드  20210516  100
# 3       서울    BB카드  20210515  100
# 4       서울    BB카드  20210514  100

# %%
data3
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       부산    AA카드  20210518  100
# 1       부산    AA카드  20210517  100
# 2       부산    AA카드  20210516  100
# 3       부산    AA카드  20210515  100
# 4       부산    AA카드  20210514  100

# %%
data4
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       부산    BB카드  20210518  100
# 1       부산    BB카드  20210517  100
# 2       부산    BB카드  20210516  100
# 3       부산    BB카드  20210515  100
# 4       부산    BB카드  20210514  100

# %%
#데이터 이어붙이기
mergedData = data1.append(data2).append(data3).append(data4)
mergedData
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       서울    AA카드  20210518  100
# 1       서울    AA카드  20210517  100
# 2       서울    AA카드  20210516  100
# 3       서울    AA카드  20210515  100
# 4       서울    AA카드  20210514  100
# 0       서울    BB카드  20210518  100
# 1       서울    BB카드  20210517  100
# 2       서울    BB카드  20210516  100
# 3       서울    BB카드  20210515  100
# 4       서울    BB카드  20210514  100
# 0       부산    AA카드  20210518  100
# 1       부산    AA카드  20210517  100
# 2       부산    AA카드  20210516  100
# 3       부산    AA카드  20210515  100
# 4       부산    AA카드  20210514  100
# 0       부산    BB카드  20210518  100
# 1       부산    BB카드  20210517  100
# 2       부산    BB카드  20210516  100
# 3       부산    BB카드  20210515  100
# 4       부산    BB카드  20210514  100

# %% [markdown]
# ### 프로모션정보

# %%
promotionColumns = ["SUBSIDIARY", "CARD_NAME", "PROMOTION_NAME", "PROMOTION_RATE"]

# %%
promotionData = pd.DataFrame([ ["서울", "AA카드", "서울_프로모션", 0.5],
                               ["부산", "BB카드", "부산_프로모션", 0.3],
                               ["부산", "CC카드", "부산_프로모션", 0.25]], columns = promotionColumns)

# %%
promotionData
# Out:
#   SUBSIDIARY CARD_NAME PROMOTION_NAME  PROMOTION_RATE
# 0         서울      AA카드        서울_프로모션            0.50
# 1         부산      BB카드        부산_프로모션            0.30
# 2         부산      CC카드        부산_프로모션            0.25

# %% [markdown]
# ### mergedData + promotionData

# %%
mergedData
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       서울    AA카드  20210518  100
# 1       서울    AA카드  20210517  100
# 2       서울    AA카드  20210516  100
# 3       서울    AA카드  20210515  100
# 4       서울    AA카드  20210514  100
# 0       서울    BB카드  20210518  100
# 1       서울    BB카드  20210517  100
# 2       서울    BB카드  20210516  100
# 3       서울    BB카드  20210515  100
# 4       서울    BB카드  20210514  100
# 0       부산    AA카드  20210518  100
# 1       부산    AA카드  20210517  100
# 2       부산    AA카드  20210516  100
# 3       부산    AA카드  20210515  100
# 4       부산    AA카드  20210514  100
# 0       부산    BB카드  20210518  100
# 1       부산    BB카드  20210517  100
# 2       부산    BB카드  20210516  100
# 3       부산    BB카드  20210515  100
# 4       부산    BB카드  20210514  100

# %%
promotionData
# Out:
#   SUBSIDIARY CARD_NAME PROMOTION_NAME  PROMOTION_RATE
# 0         서울      AA카드        서울_프로모션            0.50
# 1         부산      BB카드        부산_프로모션            0.30
# 2         부산      CC카드        부산_프로모션            0.25

# %%
# 지역 과 카드를 동시에 맵핑해준다
mergeCardData = pd.merge(left=mergedData,
                right=promotionData,
                left_on=["REGIONID","PRODUCT"], 
                right_on=["SUBSIDIARY","CARD_NAME"],
                how="left")

# %%
mergeCardData
# Out:
#    REGIONID PRODUCT      DATE  QTY SUBSIDIARY CARD_NAME PROMOTION_NAME  \
# 0        서울    AA카드  20210518  100         서울      AA카드        서울_프로모션
# 1        서울    AA카드  20210517  100         서울      AA카드        서울_프로모션
# 2        서울    AA카드  20210516  100         서울      AA카드        서울_프로모션
# 3        서울    AA카드  20210515  100         서울      AA카드        서울_프로모션
# 4        서울    AA카드  20210514  100         서울      AA카드        서울_프로모션
# 5        서울    BB카드  20210518  100        NaN       NaN            NaN
# 6        서울    BB카드  20210517  100        NaN       NaN            NaN
# 7        서울    BB카드  20210516  100        NaN       NaN            NaN
# 8        서울    BB카드  20210515  100        NaN       NaN            NaN
# 9        서울    BB카드  20210514  100        NaN       NaN            NaN
# 10       부산    AA카드  20210518  100        NaN       NaN            NaN
# 11       부산    AA카드  20210517  100        NaN       NaN            NaN
# 12       부산    AA카드  20210516  100        NaN       NaN            NaN
# 13       부산    AA카드  20210515  100        NaN       NaN            NaN
# 14       부산    AA카드  20210514  100        NaN       NaN            NaN
# 15       부산    BB카드  20210518  100         부산      BB카드        부산_프로모션
# 16       부산    BB카드  20210517  100         부산      BB카드        부산_프로모션
# 17       부산    BB카드  20210516  100         부산      BB카드        부산_프로모션
# 18       부산    BB카드  20210515  100         부산      BB카드        부산_프로모션
# 19       부산    BB카드  20210514  100         부산      BB카드        부산_프로모션
#
#     PROMOTION_RATE
# 0              0.5
# 1              0.5
# 2              0.5
# 3              0.5
# 4              0.5
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             0.3
# 16             0.3
# 17             0.3
# 18             0.3
# 19             0.3
